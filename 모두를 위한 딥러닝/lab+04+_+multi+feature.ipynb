# %% [markdown]
# # Lab 4 Multi-variable linear regression

# %%
import tensorflow as tf
tf.set_random_seed(777)  # for reproducibility

# %%
# x : mid ex
x1_data = [73., 93., 89., 96., 73.]
x2_data = [80., 88., 91., 98., 66.]
x3_data = [75., 93., 90., 100., 70.]
# y : final ex
y_data = [152., 185., 180., 196., 142.]

# %% [markdown]
# placeholders for a tensor that will be always fed.

# %%
x1 = tf.placeholder(tf.float32)
x2 = tf.placeholder(tf.float32)
x3 = tf.placeholder(tf.float32)

Y = tf.placeholder(tf.float32)

# %%
w1 = tf.Variable(tf.random_normal([1]), name='weight1')
w2 = tf.Variable(tf.random_normal([1]), name='weight2')
w3 = tf.Variable(tf.random_normal([1]), name='weight3')
b = tf.Variable(tf.random_normal([1]), name='bias')

# %%
hypothesis = x1 * w1 + x2 * w2 + x3 * w3 + b
print(hypothesis)
# Out:
# Tensor("add_2:0", dtype=float32)

# %% [markdown]
# cost/loss function

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %% [markdown]
# Minimize. Need a very small learning rate for this data set

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# %%
# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

for step in range(2001):
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train],
                                   feed_dict={x1: x1_data, x2: x2_data, x3: x3_data, Y: y_data})
    if step % 100 == 0:
        print(step, "Cost: ", cost_val, "\nPrediction:\n", hy_val)
# Out:
# 0 Cost:  62547.3
# Prediction:
#  [-75.96344757 -78.27629089 -83.83014679 -90.80435944 -56.97648239]
# 100 Cost:  13.2472
# Prediction:
#  [ 146.06376648  188.31446838  178.98654175  195.37893677  146.31259155]
# 200 Cost:  12.5621
# Prediction:
#  [ 146.20278931  188.21931458  179.02929688  195.40849304  146.18890381]
# 300 Cost:  11.9133
# Prediction:
#  [ 146.33810425  188.12670898  179.07095337  195.43722534  146.068573  ]
# 400 Cost:  11.2986
# Prediction:
#  [ 146.4697876   188.0365448   179.11146545  195.46513367  145.95143127]
# 500 Cost:  10.7164
# Prediction:
#  [ 146.59799194  187.94880676  179.15092468  195.49229431  145.83746338]
# 600 Cost:  10.1648
# Prediction:
#  [ 146.72277832  187.86340332  179.18934631  195.51869202  145.7265625 ]
# 700 Cost:  9.64238
# Prediction:
#  [ 146.84425354  187.7802887   179.22674561  195.54437256  145.61865234]
# 800 Cost:  9.14744
# Prediction:
#  [ 146.96246338  187.69935608  179.26315308  195.56930542  145.51361084]
# 900 Cost:  8.6786
# Prediction:
#  [ 147.07757568  187.62060547  179.29858398  195.59356689  145.41145325]
# 1000 Cost:  8.23449
# Prediction:
#  [ 147.18959045  187.54394531  179.33308411  195.61715698  145.31201172]
# 1100 Cost:  7.81377
# Prediction:
#  [ 147.29864502  187.46932983  179.3666687   195.64007568  145.21525574]
# 1200 Cost:  7.41522
# Prediction:
#  [ 147.40480042  187.396698    179.39938354  195.66235352  145.12110901]
# 1300 Cost:  7.0377
# Prediction:
#  [ 147.50811768  187.32600403  179.43119812  195.684021    145.02949524]
# 1400 Cost:  6.68003
# Prediction:
#  [ 147.60870361  187.25717163  179.46218872  195.70504761  144.94033813]
# 1500 Cost:  6.34126
# Prediction:
#  [ 147.706604    187.19020081  179.49237061  195.72554016  144.85360718]
# 1600 Cost:  6.02031
# Prediction:
#  [ 147.8019104   187.125       179.52174377  195.74542236  144.76919556]
# 1700 Cost:  5.71629
# Prediction:
#  [ 147.89468384  187.06155396  179.55033875  195.76475525  144.6870575 ]
# 1800 Cost:  5.4283
# Prediction:
#  [ 147.98498535  186.99978638  179.57817078  195.78353882  144.60714722]
# 1900 Cost:  5.15548
# Prediction:
#  [ 148.07289124  186.93965149  179.6053009   195.80180359  144.52940369]
# 2000 Cost:  4.89701
# Prediction:
#  [ 148.15844727  186.88110352  179.63166809  195.8195343   144.45372009]

# %% [markdown]
# ---

# %% [markdown]
# input data as matrix

# %%
x_data = [[73., 80., 75.],
          [93., 88., 93.],
          [89., 91., 90.],
          [96., 98., 100.],
          [73., 66., 70.]]
y_data = [[152.],
          [185.],
          [180.],
          [196.],
          [142.]]

# %%
# placeholders for a tensor that will be always fed.
X = tf.placeholder(tf.float32, shape=[None, 3]) # 대충 몇개다 : None
Y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([3, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# %%
# Hypothesis
hypothesis = tf.matmul(X, W) + b

# Simplified cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# %%
# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

for step in range(2001):
    cost_val, hy_val, _ = sess.run(
        [cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 100 == 0:
        print(step, "Cost: ", cost_val, "\nPrediction:\n", hy_val)
# Out:
# 0 Cost:  22712.4
# Prediction:
#  [[ 15.35308552]
#  [ 25.62049103]
#  [ 21.43587303]
#  [ 23.02159691]
#  [ 21.90162849]]
# 100 Cost:  3.20764
# Prediction:
#  [[ 149.13404846]
#  [ 186.28488159]
#  [ 179.80903625]
#  [ 195.4785614 ]
#  [ 144.42182922]]
# 200 Cost:  3.04557
# Prediction:
#  [[ 149.20123291]
#  [ 186.23880005]
#  [ 179.82958984]
#  [ 195.49372864]
#  [ 144.36109924]]
# 300 Cost:  2.89204
# Prediction:
#  [[ 149.26663208]
#  [ 186.19395447]
#  [ 179.84957886]
#  [ 195.50846863]
#  [ 144.30198669]]
# 400 Cost:  2.7466
# Prediction:
#  [[ 149.33027649]
#  [ 186.15028381]
#  [ 179.86903381]
#  [ 195.52285767]
#  [ 144.24446106]]
# 500 Cost:  2.60886
# Prediction:
#  [[ 149.39219666]
#  [ 186.10780334]
#  [ 179.88796997]
#  [ 195.53684998]
#  [ 144.1884613 ]]
# 600 Cost:  2.47837
# Prediction:
#  [[ 149.45246887]
#  [ 186.06645203]
#  [ 179.90640259]
#  [ 195.55047607]
#  [ 144.13395691]]
# 700 Cost:  2.35478
# Prediction:
#  [[ 149.51112366]
#  [ 186.0262146 ]
#  [ 179.92434692]
#  [ 195.56370544]
#  [ 144.08091736]]
# 800 Cost:  2.23769
# Prediction:
#  [[ 149.56820679]
#  [ 185.98704529]
#  [ 179.94178772]
#  [ 195.57662964]
#  [ 144.02926636]]
# 900 Cost:  2.12677
# Prediction:
#  [[ 149.62376404]
#  [ 185.94891357]
#  [ 179.95875549]
#  [ 195.58920288]
#  [ 143.97900391]]
# 1000 Cost:  2.02172
# Prediction:
#  [[ 149.67784119]
#  [ 185.91183472]
#  [ 179.97529602]
#  [ 195.60145569]
#  [ 143.93009949]]
# 1100 Cost:  1.92219
# Prediction:
#  [[ 149.73046875]
#  [ 185.87573242]
#  [ 179.99137878]
#  [ 195.6133728 ]
#  [ 143.88247681]]
# 1200 Cost:  1.82793
# Prediction:
#  [[ 149.78166199]
#  [ 185.84059143]
#  [ 180.00701904]
#  [ 195.62496948]
#  [ 143.83612061]]
# 1300 Cost:  1.73864
# Prediction:
#  [[ 149.83151245]
#  [ 185.80639648]
#  [ 180.02227783]
#  [ 195.63627625]
#  [ 143.79103088]]
# 1400 Cost:  1.65406
# Prediction:
#  [[ 149.88002014]
#  [ 185.77313232]
#  [ 180.03709412]
#  [ 195.64729309]
#  [ 143.74713135]]
# 1500 Cost:  1.57391
# Prediction:
#  [[ 149.92723083]
#  [ 185.74072266]
#  [ 180.05151367]
#  [ 195.65800476]
#  [ 143.70437622]]
# 1600 Cost:  1.49802
# Prediction:
#  [[ 149.97317505]
#  [ 185.70921326]
#  [ 180.06556702]
#  [ 195.66844177]
#  [ 143.66279602]]
# 1700 Cost:  1.42612
# Prediction:
#  [[ 150.01786804]
#  [ 185.67851257]
#  [ 180.07920837]
#  [ 195.67858887]
#  [ 143.62228394]]
# 1800 Cost:  1.35802
# Prediction:
#  [[ 150.06138611]
#  [ 185.64866638]
#  [ 180.09251404]
#  [ 195.68852234]
#  [ 143.58288574]]
# 1900 Cost:  1.29351
# Prediction:
#  [[ 150.10371399]
#  [ 185.61959839]
#  [ 180.10542297]
#  [ 195.69810486]
#  [ 143.54450989]]
# 2000 Cost:  1.23242
# Prediction:
#  [[ 150.14492798]
#  [ 185.59135437]
#  [ 180.11804199]
#  [ 195.70751953]
#  [ 143.50718689]]

# %% [markdown]
# ---

# %% [markdown]
# # how to import data

# %%
import numpy as np

# %%
xy = np.loadtxt('data-01-test-score.csv', delimiter=',', dtype=np.float32)
xy
# Out:
# array([[  73.,   80.,   75.,  152.],
#        [  93.,   88.,   93.,  185.],
#        [  89.,   91.,   90.,  180.],
#        [  96.,   98.,  100.,  196.],
#        [  73.,   66.,   70.,  142.],
#        [  53.,   46.,   55.,  101.],
#        [  69.,   74.,   77.,  149.],
#        [  47.,   56.,   60.,  115.],
#        [  87.,   79.,   90.,  175.],
#        [  79.,   70.,   88.,  164.],
#        [  69.,   70.,   73.,  141.],
#        [  70.,   65.,   74.,  141.],
#        [  93.,   95.,   91.,  184.],
#        [  79.,   80.,   73.,  152.],
#        [  70.,   73.,   78.,  148.],
#        [  93.,   89.,   96.,  192.],
#        [  78.,   75.,   68.,  147.],
#        [  81.,   90.,   93.,  183.],
#        [  88.,   92.,   86.,  177.],
#        [  78.,   83.,   77.,  159.],
#        [  82.,   86.,   90.,  177.],
#        [  86.,   82.,   89.,  175.],
#        [  78.,   83.,   85.,  175.],
#        [  76.,   83.,   71.,  149.],
#        [  96.,   93.,   95.,  192.]], dtype=float32)

# %%
x_data = xy[:, 0:-1]
y_data = xy[:, [-1]]

# %%
# Make sure the shape and data are OK
print(x_data.shape, x_data, len(x_data))
print(y_data.shape, y_data)
# Out:
# (25, 3) [[  73.   80.   75.]
#  [  93.   88.   93.]
#  [  89.   91.   90.]
#  [  96.   98.  100.]
#  [  73.   66.   70.]
#  [  53.   46.   55.]
#  [  69.   74.   77.]
#  [  47.   56.   60.]
#  [  87.   79.   90.]
#  [  79.   70.   88.]
#  [  69.   70.   73.]
#  [  70.   65.   74.]
#  [  93.   95.   91.]
#  [  79.   80.   73.]
#  [  70.   73.   78.]
#  [  93.   89.   96.]
#  [  78.   75.   68.]
#  [  81.   90.   93.]
#  [  88.   92.   86.]
#  [  78.   83.   77.]
#  [  82.   86.   90.]
#  [  86.   82.   89.]
#  [  78.   83.   85.]
#  [  76.   83.   71.]
#  [  96.   93.   95.]] 25
# (25, 1) [[ 152.]
#  [ 185.]
#  [ 180.]
#  [ 196.]
#  [ 142.]
#  [ 101.]
#  [ 149.]
#  [ 115.]
#  [ 175.]
#  [ 164.]
#  [ 141.]
#  [ 141.]
#  [ 184.]
#  [ 152.]
#  [ 148.]
#  [ 192.]
#  [ 147.]
#  [ 183.]
#  [ 177.]
#  [ 159.]
#  [ 177.]
#  [ 175.]
#  [ 175.]
#  [ 149.]
#  [ 192.]]

# %%
# placeholders for a tensor that will be always fed.
X = tf.placeholder(tf.float32, shape=[None, 3])
Y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([3, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# %%
# Hypothesis
hypothesis = tf.matmul(X, W) + b

# Simplified cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# %%
# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

for step in range(2001):
    cost_val, hy_val, _ = sess.run(
        [cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 100 == 0:
        print(step, "Cost: ", cost_val, "\nPrediction:\n", hy_val)
# Out:
# 0 Cost:  10808.6
# Prediction:
#  [[ 251.09085083]
#  [ 301.1428833 ]
#  [ 296.89666748]
#  [ 325.21548462]
#  [ 227.97183228]
#  [ 170.902771  ]
#  [ 246.41296387]
#  [ 186.85440063]
#  [ 283.58547974]
#  [ 266.76095581]
#  [ 235.29014587]
#  [ 232.43911743]
#  [ 304.79696655]
#  [ 250.6489563 ]
#  [ 247.65771484]
#  [ 307.43710327]
#  [ 236.23348999]
#  [ 297.04751587]
#  [ 290.38162231]
#  [ 260.23590088]
#  [ 288.19338989]
#  [ 284.38858032]
#  [ 274.29000854]
#  [ 248.67144775]
#  [ 311.31192017]]
# 100 Cost:  7.55182
# Prediction:
#  [[ 153.37205505]
#  [ 183.71385193]
#  [ 181.1831665 ]
#  [ 199.17666626]
#  [ 138.43284607]
#  [ 104.86376953]
#  [ 152.03604126]
#  [ 116.84312439]
#  [ 173.82226562]
#  [ 165.05543518]
#  [ 144.38729858]
#  [ 142.80888367]
#  [ 185.26777649]
#  [ 151.31236267]
#  [ 152.84797668]
#  [ 188.25523376]
#  [ 141.65652466]
#  [ 183.77000427]
#  [ 176.42744446]
#  [ 158.26860046]
#  [ 177.53079224]
#  [ 174.20552063]
#  [ 168.78536987]
#  [ 150.19117737]
#  [ 189.61573792]]
# 200 Cost:  7.4734
# Prediction:
#  [[ 153.37026978]
#  [ 183.73199463]
#  [ 181.19203186]
#  [ 199.16885376]
#  [ 138.46607971]
#  [ 104.86357117]
#  [ 151.9984436 ]
#  [ 116.77025604]
#  [ 173.82250977]
#  [ 165.01876831]
#  [ 144.37506104]
#  [ 142.79902649]
#  [ 185.29528809]
#  [ 151.36166382]
#  [ 152.8112793 ]
#  [ 188.25508118]
#  [ 141.73101807]
#  [ 183.70916748]
#  [ 176.45333862]
#  [ 158.28637695]
#  [ 177.49586487]
#  [ 174.20410156]
#  [ 168.75534058]
#  [ 150.23176575]
#  [ 189.63964844]]
# 300 Cost:  7.39951
# Prediction:
#  [[ 153.36817932]
#  [ 183.74984741]
#  [ 181.20053101]
#  [ 199.16123962]
#  [ 138.49861145]
#  [ 104.8638382 ]
#  [ 151.96185303]
#  [ 116.69939423]
#  [ 173.82325745]
#  [ 164.9839325 ]
#  [ 144.36322021]
#  [ 142.7898407 ]
#  [ 185.3217926 ]
#  [ 151.40922546]
#  [ 152.7756958 ]
#  [ 188.25520325]
#  [ 141.80314636]
#  [ 183.6499176 ]
#  [ 176.47813416]
#  [ 158.30326843]
#  [ 177.46192932]
#  [ 174.20303345]
#  [ 168.72607422]
#  [ 150.27056885]
#  [ 189.66294861]]
# 400 Cost:  7.32981
# Prediction:
#  [[ 153.36578369]
#  [ 183.76741028]
#  [ 181.20866394]
#  [ 199.15383911]
#  [ 138.53050232]
#  [ 104.86450958]
#  [ 151.92628479]
#  [ 116.63045502]
#  [ 173.82449341]
#  [ 164.95088196]
#  [ 144.35177612]
#  [ 142.78129578]
#  [ 185.3473053 ]
#  [ 151.45516968]
#  [ 152.74119568]
#  [ 188.25561523]
#  [ 141.87303162]
#  [ 183.59222412]
#  [ 176.50190735]
#  [ 158.31933594]
#  [ 177.4289856 ]
#  [ 174.20227051]
#  [ 168.69758606]
#  [ 150.30767822]
#  [ 189.6856842 ]]
# 500 Cost:  7.2641
# Prediction:
#  [[ 153.36306763]
#  [ 183.78466797]
#  [ 181.21640015]
#  [ 199.14656067]
#  [ 138.56164551]
#  [ 104.86555481]
#  [ 151.89163208]
#  [ 116.56337738]
#  [ 173.8261261 ]
#  [ 164.91943359]
#  [ 144.34063721]
#  [ 142.77331543]
#  [ 185.37182617]
#  [ 151.49945068]
#  [ 152.7077179 ]
#  [ 188.25621033]
#  [ 141.94067383]
#  [ 183.53599548]
#  [ 176.52461243]
#  [ 158.33456421]
#  [ 177.39692688]
#  [ 174.20175171]
#  [ 168.66975403]
#  [ 150.34310913]
#  [ 189.70779419]]
# 600 Cost:  7.20209
# Prediction:
#  [[ 153.36010742]
#  [ 183.80166626]
#  [ 181.22381592]
#  [ 199.13948059]
#  [ 138.5921936 ]
#  [ 104.86697388]
#  [ 151.85795593]
#  [ 116.49812317]
#  [ 173.82820129]
#  [ 164.88961792]
#  [ 144.32989502]
#  [ 142.76593018]
#  [ 185.39546204]
#  [ 151.54222107]
#  [ 152.67526245]
#  [ 188.25708008]
#  [ 142.00621033]
#  [ 183.48126221]
#  [ 176.54640198]
#  [ 158.34906006]
#  [ 177.36581421]
#  [ 174.20152283]
#  [ 168.64268494]
#  [ 150.3769989 ]
#  [ 189.72940063]]
# 700 Cost:  7.14358
# Prediction:
#  [[ 153.35690308]
#  [ 183.81834412]
#  [ 181.230896  ]
#  [ 199.13256836]
#  [ 138.62203979]
#  [ 104.86871338]
#  [ 151.82516479]
#  [ 116.43464661]
#  [ 173.83062744]
#  [ 164.86128235]
#  [ 144.31944275]
#  [ 142.75906372]
#  [ 185.41819763]
#  [ 151.58349609]
#  [ 152.64376831]
#  [ 188.25814819]
#  [ 142.06967163]
#  [ 183.427948  ]
#  [ 176.56726074]
#  [ 158.36280823]
#  [ 177.33557129]
#  [ 174.20153809]
#  [ 168.61627197]
#  [ 150.40939331]
#  [ 189.75042725]]
# 800 Cost:  7.08834
# Prediction:
#  [[ 153.35348511]
#  [ 183.83474731]
#  [ 181.2376709 ]
#  [ 199.12580872]
#  [ 138.65127563]
#  [ 104.8707428 ]
#  [ 151.79325867]
#  [ 116.37285614]
#  [ 173.83340454]
#  [ 164.8343811 ]
#  [ 144.30934143]
#  [ 142.75270081]
#  [ 185.44009399]
#  [ 151.62333679]
#  [ 152.61320496]
#  [ 188.25939941]
#  [ 142.13119507]
#  [ 183.37597656]
#  [ 176.58721924]
#  [ 158.37585449]
#  [ 177.30615234]
#  [ 174.20175171]
#  [ 168.5905304 ]
#  [ 150.44033813]
#  [ 189.77090454]]
# 900 Cost:  7.0362
# Prediction:
#  [[ 153.34985352]
#  [ 183.8508606 ]
#  [ 181.24414062]
#  [ 199.11920166]
#  [ 138.67985535]
#  [ 104.87308502]
#  [ 151.76220703]
#  [ 116.3127594 ]
#  [ 173.83650208]
#  [ 164.80886841]
#  [ 144.29954529]
#  [ 142.74681091]
#  [ 185.46118164]
#  [ 151.6618042 ]
#  [ 152.58355713]
#  [ 188.26083374]
#  [ 142.19076538]
#  [ 183.32540894]
#  [ 176.6063385 ]
#  [ 158.38824463]
#  [ 177.27758789]
#  [ 174.20219421]
#  [ 168.56546021]
#  [ 150.46994019]
#  [ 189.79086304]]
# 1000 Cost:  6.98698
# Prediction:
#  [[ 153.34603882]
#  [ 183.8666687 ]
#  [ 181.25030518]
#  [ 199.11276245]
#  [ 138.70782471]
#  [ 104.87566376]
#  [ 151.73199463]
#  [ 116.25426483]
#  [ 173.83987427]
#  [ 164.78465271]
#  [ 144.29003906]
#  [ 142.74137878]
#  [ 185.48147583]
#  [ 151.69894409]
#  [ 152.55477905]
#  [ 188.26242065]
#  [ 142.24847412]
#  [ 183.27609253]
#  [ 176.62463379]
#  [ 158.3999939 ]
#  [ 177.24980164]
#  [ 174.20281982]
#  [ 168.54098511]
#  [ 150.49819946]
#  [ 189.81033325]]
# 1100 Cost:  6.94047
# Prediction:
#  [[ 153.34204102]
#  [ 183.88223267]
#  [ 181.25619507]
#  [ 199.10646057]
#  [ 138.73516846]
#  [ 104.87850952]
#  [ 151.70257568]
#  [ 116.19735718]
#  [ 173.84353638]
#  [ 164.76168823]
#  [ 144.28082275]
#  [ 142.73635864]
#  [ 185.50102234]
#  [ 151.73478699]
#  [ 152.52685547]
#  [ 188.26416016]
#  [ 142.30439758]
#  [ 183.22808838]
#  [ 176.6421814 ]
#  [ 158.41113281]
#  [ 177.22279358]
#  [ 174.20362854]
#  [ 168.51715088]
#  [ 150.52522278]
#  [ 189.82928467]]
# 1200 Cost:  6.89654
# Prediction:
#  [[ 153.33787537]
#  [ 183.89746094]
#  [ 181.2618103 ]
#  [ 199.10031128]
#  [ 138.76193237]
#  [ 104.88154602]
#  [ 151.6739502 ]
#  [ 116.14196777]
#  [ 173.84742737]
#  [ 164.73988342]
#  [ 144.27189636]
#  [ 142.73175049]
#  [ 185.51983643]
#  [ 151.76940918]
#  [ 152.4997406 ]
#  [ 188.26602173]
#  [ 142.35858154]
#  [ 183.18127441]
#  [ 176.65893555]
#  [ 158.42170715]
#  [ 177.1965332 ]
#  [ 174.2046051 ]
#  [ 168.49389648]
#  [ 150.55102539]
#  [ 189.8477478 ]]
# 1300 Cost:  6.85503
# Prediction:
#  [[ 153.33358765]
#  [ 183.91244507]
#  [ 181.2671814 ]
#  [ 199.09429932]
#  [ 138.7881012 ]
#  [ 104.8848114 ]
#  [ 151.64607239]
#  [ 116.08807373]
#  [ 173.8515625 ]
#  [ 164.71922302]
#  [ 144.26324463]
#  [ 142.72750854]
#  [ 185.53796387]
#  [ 151.80285645]
#  [ 152.47344971]
#  [ 188.26803589]
#  [ 142.41110229]
#  [ 183.13571167]
#  [ 176.67501831]
#  [ 158.43173218]
#  [ 177.17100525]
#  [ 174.20574951]
#  [ 168.47123718]
#  [ 150.57571411]
#  [ 189.86575317]]
# 1400 Cost:  6.81578
# Prediction:
#  [[ 153.32917786]
#  [ 183.9271698 ]
#  [ 181.27235413]
#  [ 199.0884552 ]
#  [ 138.8137207 ]
#  [ 104.88825989]
#  [ 151.61897278]
#  [ 116.03562164]
#  [ 173.85591125]
#  [ 164.69966125]
#  [ 144.25486755]
#  [ 142.72366333]
#  [ 185.5554657 ]
#  [ 151.8351593 ]
#  [ 152.44792175]
#  [ 188.27018738]
#  [ 142.46203613]
#  [ 183.09132385]
#  [ 176.69042969]
#  [ 158.4412384 ]
#  [ 177.14620972]
#  [ 174.20704651]
#  [ 168.44917297]
#  [ 150.59931946]
#  [ 189.88331604]]
# 1500 Cost:  6.77869
# Prediction:
#  [[ 153.32466125]
#  [ 183.94160461]
#  [ 181.27723694]
#  [ 199.0827179 ]
#  [ 138.83876038]
#  [ 104.89186859]
#  [ 151.59257507]
#  [ 115.98456573]
#  [ 173.86042786]
#  [ 164.68109131]
#  [ 144.24671936]
#  [ 142.72013855]
#  [ 185.57228088]
#  [ 151.86636353]
#  [ 152.42314148]
#  [ 188.27241516]
#  [ 142.5113678 ]
#  [ 183.04808044]
#  [ 176.70515442]
#  [ 158.45024109]
#  [ 177.12207031]
#  [ 174.20845032]
#  [ 168.42762756]
#  [ 150.62184143]
#  [ 189.90042114]]
# 1600 Cost:  6.7436
# Prediction:
#  [[ 153.32003784]
#  [ 183.95578003]
#  [ 181.28193665]
#  [ 199.07714844]
#  [ 138.86325073]
#  [ 104.89564514]
#  [ 151.56689453]
#  [ 115.93487549]
#  [ 173.86514282]
#  [ 164.66352844]
#  [ 144.23883057]
#  [ 142.7169342 ]
#  [ 185.58850098]
#  [ 151.89651489]
#  [ 152.39907837]
#  [ 188.27476501]
#  [ 142.55921936]
#  [ 183.00593567]
#  [ 176.71928406]
#  [ 158.45878601]
#  [ 177.09863281]
#  [ 174.21000671]
#  [ 168.40666199]
#  [ 150.64338684]
#  [ 189.917099  ]]
# 1700 Cost:  6.71043
# Prediction:
#  [[ 153.31529236]
#  [ 183.96966553]
#  [ 181.28640747]
#  [ 199.07168579]
#  [ 138.88717651]
#  [ 104.89954376]
#  [ 151.54185486]
#  [ 115.8864975 ]
#  [ 173.86999512]
#  [ 164.64685059]
#  [ 144.23117065]
#  [ 142.71401978]
#  [ 185.60409546]
#  [ 151.9256134 ]
#  [ 152.3757019 ]
#  [ 188.27716064]
#  [ 142.60557556]
#  [ 182.96487427]
#  [ 176.73278809]
#  [ 158.46684265]
#  [ 177.07580566]
#  [ 174.2116394 ]
#  [ 168.38618469]
#  [ 150.66395569]
#  [ 189.93334961]]
# 1800 Cost:  6.67904
# Prediction:
#  [[ 153.3105011 ]
#  [ 183.98329163]
#  [ 181.29067993]
#  [ 199.06636047]
#  [ 138.91059875]
#  [ 104.90357971]
#  [ 151.51750183]
#  [ 115.8394165 ]
#  [ 173.87498474]
#  [ 164.63108826]
#  [ 144.22375488]
#  [ 142.71141052]
#  [ 185.61915588]
#  [ 151.95375061]
#  [ 152.35302734]
#  [ 188.27967834]
#  [ 142.65054321]
#  [ 182.92488098]
#  [ 176.7457428 ]
#  [ 158.47450256]
#  [ 177.05361938]
#  [ 174.21339417]
#  [ 168.36625671]
#  [ 150.68363953]
#  [ 189.94917297]]
# 1900 Cost:  6.64935
# Prediction:
#  [[ 153.30566406]
#  [ 183.9967041 ]
#  [ 181.2947998 ]
#  [ 199.06118774]
#  [ 138.9335022 ]
#  [ 104.90773773]
#  [ 151.49382019]
#  [ 115.79360962]
#  [ 173.88014221]
#  [ 164.61618042]
#  [ 144.21656799]
#  [ 142.70907593]
#  [ 185.63366699]
#  [ 151.98095703]
#  [ 152.33102417]
#  [ 188.2822876 ]
#  [ 142.69415283]
#  [ 182.88592529]
#  [ 176.75817871]
#  [ 158.48176575]
#  [ 177.03207397]
#  [ 174.215271  ]
#  [ 168.34683228]
#  [ 150.70245361]
#  [ 189.96463013]]
# 2000 Cost:  6.62127
# Prediction:
#  [[ 153.30073547]
#  [ 184.0098114 ]
#  [ 181.2986908 ]
#  [ 199.05610657]
#  [ 138.95588684]
#  [ 104.9119873 ]
#  [ 151.47073364]
#  [ 115.74900055]
#  [ 173.88536072]
#  [ 164.60206604]
#  [ 144.20959473]
#  [ 142.70698547]
#  [ 185.6476593 ]
#  [ 152.00724792]
#  [ 152.30964661]
#  [ 188.28491211]
#  [ 142.73641968]
#  [ 182.84794617]
#  [ 176.77005005]
#  [ 158.48861694]
#  [ 177.01109314]
#  [ 174.21720886]
#  [ 168.32788086]
#  [ 150.72039795]
#  [ 189.97969055]]

# %%
# Ask my score
print("Your score will be ", sess.run(
    hypothesis, feed_dict={X: [[100, 70, 101]]}))

print("Other scores will be ", sess.run(hypothesis,
                                        feed_dict={X: [[60, 70, 110], [90, 100, 80]]}))
# Out:
# Your score will be  [[ 184.67326355]]
# Other scores will be  [[ 187.96507263]
#  [ 174.46272278]]

# %% [markdown]
# ---

# %% [markdown]
# # Queue Runners

# %%
filename_queue = tf.train.string_input_producer(
    ['data-01-test-score.csv'], shuffle=False, name='filename_queue')

# %%
reader = tf.TextLineReader()
key, value = reader.read(filename_queue)

# %% [markdown]
# data type

# %%
# Default values, in case of empty columns. Also specifies the type of the
# decoded result.
record_defaults = [[0.], [0.], [0.], [0.]]
xy = tf.decode_csv(value, record_defaults=record_defaults)

# %% [markdown]
# batch

# %%
# collect batches of csv in
train_x_batch, train_y_batch = \
    tf.train.batch([xy[0:-1], xy[-1:]], batch_size=10)

# %%
# placeholders for a tensor that will be always fed.
X = tf.placeholder(tf.float32, shape=[None, 3])
Y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([3, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# %%
# Hypothesis
hypothesis = tf.matmul(X, W) + b

# Simplified cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# %%
# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

# Start populating the filename queue.
coord = tf.train.Coordinator()
threads = tf.train.start_queue_runners(sess=sess, coord=coord)

for step in range(2001):
    x_batch, y_batch = sess.run([train_x_batch, train_y_batch])
    cost_val, hy_val, _ = sess.run(
        [cost, hypothesis, train], feed_dict={X: x_batch, Y: y_batch})
    if step % 100 == 0:
        print(step, "Cost: ", cost_val, "\nPrediction:\n", hy_val)

coord.request_stop()
coord.join(threads)
# Out:
# 0 Cost:  10982.9
# Prediction:
#  [[ 51.74819565]
#  [ 62.83285141]
#  [ 61.42819977]
#  [ 66.74022675]
#  [ 48.58052063]
#  [ 36.37724686]
#  [ 50.10719681]
#  [ 37.16603851]
#  [ 59.05656052]
#  [ 54.90377426]]
# 100 Cost:  6.51679
# Prediction:
#  [[ 153.86054993]
#  [ 185.62568665]
#  [ 182.38124084]
#  [ 198.51812744]
#  [ 142.20376587]
#  [ 105.4876709 ]
#  [ 148.8054657 ]
#  [ 110.41400146]
#  [ 173.89198303]
#  [ 161.38737488]]
# 200 Cost:  6.33336
# Prediction:
#  [[ 153.82461548]
#  [ 185.62245178]
#  [ 182.35379028]
#  [ 198.53318787]
#  [ 142.17410278]
#  [ 105.53979492]
#  [ 148.87236023]
#  [ 110.54018402]
#  [ 173.95315552]
#  [ 161.54696655]]
# 300 Cost:  6.16688
# Prediction:
#  [[ 153.79086304]
#  [ 185.61859131]
#  [ 182.32756042]
#  [ 198.54779053]
#  [ 142.14463806]
#  [ 105.58893585]
#  [ 148.93716431]
#  [ 110.66249084]
#  [ 174.01080322]
#  [ 161.69903564]]
# 400 Cost:  6.01576
# Prediction:
#  [[ 153.75921631]
#  [ 185.61418152]
#  [ 182.30249023]
#  [ 198.56196594]
#  [ 142.11535645]
#  [ 105.63520813]
#  [ 148.99998474]
#  [ 110.78105164]
#  [ 174.06510925]
#  [ 161.84399414]]
# 500 Cost:  5.87862
# Prediction:
#  [[ 153.72953796]
#  [ 185.60920715]
#  [ 182.27851868]
#  [ 198.57568359]
#  [ 142.08630371]
#  [ 105.67877197]
#  [ 149.06082153]
#  [ 110.89598083]
#  [ 174.1162262 ]
#  [ 161.98210144]]
# 600 Cost:  5.75423
# Prediction:
#  [[ 153.70173645]
#  [ 185.60375977]
#  [ 182.25561523]
#  [ 198.58898926]
#  [ 142.05749512]
#  [ 105.71977234]
#  [ 149.11979675]
#  [ 111.00740051]
#  [ 174.16433716]
#  [ 162.11369324]]
# 700 Cost:  5.64139
# Prediction:
#  [[ 153.6756897 ]
#  [ 185.59785461]
#  [ 182.23370361]
#  [ 198.60188293]
#  [ 142.02893066]
#  [ 105.7583313 ]
#  [ 149.17694092]
#  [ 111.11544037]
#  [ 174.20957947]
#  [ 162.23907471]]
# 800 Cost:  5.53909
# Prediction:
#  [[ 153.65135193]
#  [ 185.59153748]
#  [ 182.21278381]
#  [ 198.61439514]
#  [ 142.00065613]
#  [ 105.79457092]
#  [ 149.23236084]
#  [ 111.22019196]
#  [ 174.25212097]
#  [ 162.35853577]]
# 900 Cost:  5.44635
# Prediction:
#  [[ 153.62858582]
#  [ 185.58482361]
#  [ 182.19276428]
#  [ 198.62652588]
#  [ 141.97264099]
#  [ 105.82860565]
#  [ 149.28605652]
#  [ 111.32178497]
#  [ 174.29205322]
#  [ 162.4723053 ]]
# 1000 Cost:  5.36231
# Prediction:
#  [[ 153.60734558]
#  [ 185.57778931]
#  [ 182.17362976]
#  [ 198.63829041]
#  [ 141.94493103]
#  [ 105.86055756]
#  [ 149.33810425]
#  [ 111.42031097]
#  [ 174.32954407]
#  [ 162.58070374]]
# 1100 Cost:  5.28619
# Prediction:
#  [[ 153.58753967]
#  [ 185.57041931]
#  [ 182.15534973]
#  [ 198.64968872]
#  [ 141.91749573]
#  [ 105.89053345]
#  [ 149.38856506]
#  [ 111.51586914]
#  [ 174.36471558]
#  [ 162.68395996]]
# 1200 Cost:  5.21727
# Prediction:
#  [[ 153.56907654]
#  [ 185.5627594 ]
#  [ 182.13787842]
#  [ 198.6607666 ]
#  [ 141.89039612]
#  [ 105.91863251]
#  [ 149.43751526]
#  [ 111.60857391]
#  [ 174.39767456]
#  [ 162.7822876 ]]
# 1300 Cost:  5.15489
# Prediction:
#  [[ 153.5519104 ]
#  [ 185.55487061]
#  [ 182.12117004]
#  [ 198.67150879]
#  [ 141.86361694]
#  [ 105.94495392]
#  [ 149.48497009]
#  [ 111.69849396]
#  [ 174.42857361]
#  [ 162.8759613 ]]
# 1400 Cost:  5.09845
# Prediction:
#  [[ 153.53594971]
#  [ 185.54672241]
#  [ 182.10519409]
#  [ 198.68191528]
#  [ 141.8371582 ]
#  [ 105.9695816 ]
#  [ 149.53097534]
#  [ 111.78572845]
#  [ 174.45747375]
#  [ 162.96514893]]
# 1500 Cost:  5.04743
# Prediction:
#  [[ 153.52113342]
#  [ 185.53837585]
#  [ 182.08992004]
#  [ 198.6920166 ]
#  [ 141.81105042]
#  [ 105.99261475]
#  [ 149.5756073 ]
#  [ 111.87036896]
#  [ 174.48448181]
#  [ 163.0500946 ]]
# 1600 Cost:  5.00132
# Prediction:
#  [[ 153.50740051]
#  [ 185.52983093]
#  [ 182.07530212]
#  [ 198.70181274]
#  [ 141.78523254]
#  [ 106.01412201]
#  [ 149.61888123]
#  [ 111.95248413]
#  [ 174.50971985]
#  [ 163.13093567]]
# 1700 Cost:  4.95971
# Prediction:
#  [[ 153.49472046]
#  [ 185.52114868]
#  [ 182.06137085]
#  [ 198.71133423]
#  [ 141.75982666]
#  [ 106.03420258]
#  [ 149.66088867]
#  [ 112.03218842]
#  [ 174.53329468]
#  [ 163.20796204]]
# 1800 Cost:  4.92215
# Prediction:
#  [[ 153.48300171]
#  [ 185.51229858]
#  [ 182.04801941]
#  [ 198.7205658 ]
#  [ 141.73474121]
#  [ 106.05293274]
#  [ 149.70159912]
#  [ 112.10954285]
#  [ 174.55526733]
#  [ 163.28125   ]]
# 1900 Cost:  4.88826
# Prediction:
#  [[ 153.47218323]
#  [ 185.50332642]
#  [ 182.0352478 ]
#  [ 198.72952271]
#  [ 141.70999146]
#  [ 106.07034302]
#  [ 149.74110413]
#  [ 112.1845932 ]
#  [ 174.57568359]
#  [ 163.35101318]]
# 2000 Cost:  4.8578
# Prediction:
#  [[ 153.46228027]
#  [ 185.49429321]
#  [ 182.02307129]
#  [ 198.73823547]
#  [ 141.68563843]
#  [ 106.08656311]
#  [ 149.77946472]
#  [ 112.25745392]
#  [ 174.59472656]
#  [ 163.41744995]]

# %%
# Ask my score
print("Your score will be ",
      sess.run(hypothesis, feed_dict={X: [[100, 70, 101]]}))

print("Other scores will be ",
      sess.run(hypothesis, feed_dict={X: [[60, 70, 110], [90, 100, 80]]}))
# Out:
# Your score will be  [[ 187.02101135]]
# Other scores will be  [[ 171.65446472]
#  [ 177.97869873]]

# %% [markdown]
# shuffle_batch

# %%
min_after_dequeue = 10
batch_size = 5
capacity = min_after_dequeue + 3 * batch_size

# %%
example_batch, label_batch = tf.train.shuffle_batchu(
[example, label], batch_size = batch_size, capacity = capacity,
min_after_dequeue = min_after_dequeue)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-fb75b1dd04bf> in <module>()
# ----> 1 example_batch, label_batch = tf.train.shuffle_batchu(
#       2 [example, label], batch_size = batch_size, capacity = capacity,
#       3 min_after_dequeue = min_after_dequeue)
#
# AttributeError: module 'tensorflow.python.training.training' has no attribute 'shuffle_batchu'
